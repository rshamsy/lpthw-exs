# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
trainDF = pd.read_csv("/Users/MHK/Documents/Rahim/Western/Software/Python/ipython_test/av_martsales/Train.csv\
")

# %%
trainDF
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 7              FDP10          NaN          Low Fat         0.127470
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 10             FDY07       11.800          Low Fat         0.000000
# 11             FDA03       18.500          Regular         0.045464
# 12             FDX32       15.100          Regular         0.100014
# ...

# %%
trainDF.sort(columns='Item_Identifier')
# Out:
# /Users/MHK/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8043           DRA12       11.600          Low Fat         0.068535
# 118            DRA12       11.600          Low Fat         0.041178
# 1693           DRA12       11.600               LF         0.000000
# 1197           DRA12       11.600          Low Fat         0.000000
# 1245           DRA12       11.600          Low Fat         0.040912
# 7467           DRA12       11.600          Low Fat         0.041113
# 8195           DRA24       19.350          Regular         0.039895
# 6863           DRA24       19.350          Regular         0.039990
# 2879           DRA24          NaN          Regular         0.069909
# 4416           DRA24          NaN          Regular         0.039735
# ...

# %%
trainDF.sort_values(by="Item_Identifier")
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8043           DRA12       11.600          Low Fat         0.068535
# 118            DRA12       11.600          Low Fat         0.041178
# 1693           DRA12       11.600               LF         0.000000
# 1197           DRA12       11.600          Low Fat         0.000000
# 1245           DRA12       11.600          Low Fat         0.040912
# 7467           DRA12       11.600          Low Fat         0.041113
# 8195           DRA24       19.350          Regular         0.039895
# 6863           DRA24       19.350          Regular         0.039990
# 2879           DRA24          NaN          Regular         0.069909
# 4416           DRA24          NaN          Regular         0.039735
# 4900           DRA24       19.350          Regular         0.039921
# 4130           DRA24       19.350          Regular         0.066832
# 1148           DRA24       19.350          Regular         0.040154
# ...

# %%
trainDF.loc[trainDF['Item_Identifier'] == "DRA12",["Item_Weight","Item_Visibility"]]
# Out:
#       Item_Weight  Item_Visibility
# 118          11.6         0.041178
# 1197         11.6         0.000000
# 1245         11.6         0.040912
# 1693         11.6         0.000000
# 7467         11.6         0.041113
# 8043         11.6         0.068535

# %%
averageProductSales=trainDF.pivot_table(values = 'Item_Outlet_Sales',index = ['Outlet_Identifier'],aggfunc=pd.Series.nunique)

# %%
print(averageProductSales.size)
print(averageProductSales)
# Out:
# 10
# Outlet_Identifier
# OUT010    391.0
# OUT013    788.0
# OUT017    777.0
# OUT018    779.0
# OUT019    368.0
# OUT027    827.0
# OUT035    806.0
# OUT045    776.0
# OUT046    778.0
# OUT049    785.0
# Name: Item_Outlet_Sales, dtype: float64

# %%
help(pd.Series.nunique)
# Out:
# Help on function nunique in module pandas.core.base:
#
# nunique(self, dropna=True)
#     Return number of unique elements in the object.
#
#     Excludes NA values by default.
#
#     Parameters
#     ----------
#     dropna : boolean, default True
#         Don't include NaN in the count.
#
#     Returns
#     -------
#     nunique : int

# %%
def numUnique(x):
    return x.nunique

# %%
trainDF.apply(numUnique,axis=0)
# Out:
# Item_Identifier              <bound method IndexOpsMixin.nunique of 0      ...
# Item_Weight                  <bound method IndexOpsMixin.nunique of 0      ...
# Item_Fat_Content             <bound method IndexOpsMixin.nunique of 0      ...
# Item_Visibility              <bound method IndexOpsMixin.nunique of 0      ...
# Item_Type                    <bound method IndexOpsMixin.nunique of 0      ...
# Item_MRP                     <bound method IndexOpsMixin.nunique of 0      ...
# Outlet_Identifier            <bound method IndexOpsMixin.nunique of 0      ...
# Outlet_Establishment_Year    <bound method IndexOpsMixin.nunique of 0      ...
# Outlet_Size                  <bound method IndexOpsMixin.nunique of 0      ...
# Outlet_Location_Type         <bound method IndexOpsMixin.nunique of 0      ...
# Outlet_Type                  <bound method IndexOpsMixin.nunique of 0      ...
# Item_Outlet_Sales            <bound method IndexOpsMixin.nunique of 0      ...
# dtype: object
